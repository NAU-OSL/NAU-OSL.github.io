# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "confs.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    "journal":{
        "file": "journals.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED DBLP:conf/esem/Nascimento0OPSC19: " Understanding Development Process of Machine Learning System ... "
# SUCESSFULLY PARSED DBLP:conf/icse/IaffaldanoSCGL19: " Why do developers take breaks from contributing to {OSS} pro ... "
# SUCESSFULLY PARSED DBLP:conf/icse/WesselSWG19: " Should {I} stale or should {I} close?: an analysis of a bot  ... "
# SUCESSFULLY PARSED DBLP:conf/icse/0001FSSM19: " Training software engineers using open-source software: the  ... "
# SUCESSFULLY PARSED DBLP:conf/oss/FronchettiW0S19: " What Attracts Newcomers to Onboard on {OSS} Projects? TL;DR: ... "
# SUCESSFULLY PARSED DBLP:conf/sbes/PachecoWSC019: " How Open is the {SBES} {PC} Community?  "
# SUCESSFULLY PARSED DBLP:conf/sbes/LopesSC19: " {UML} Acceptance: Analyzing the Students' Perception of {UML ... "
# WARNING Missing Expected Field 'author' from entry DBLP:conf/icse/2019chase: " Proceedings of the 12th Intern ... "
# SUCESSFULLY PARSED DBLP:conf/icse/ZanattaMS18: " Competence, Collaboration, and Time Management: Barriers and ... "
# SUCESSFULLY PARSED DBLP:conf/icse/0001DS18: " Who gets a patch accepted first?: comparing the contribution ... "
# SUCESSFULLY PARSED DBLP:conf/icse/Steinmacher0WG18: " Almost there: a study on quasi-contributors in open source s ... "
# SUCESSFULLY PARSED DBLP:conf/icse/AnicheTSW0SG18: " How modern news aggregators help development communities sha ... "
# SUCESSFULLY PARSED DBLP:conf/ihc/ToscaniGSM18: " A Gamification Proposal to Support the Onboarding of Newcome ... "
# SUCESSFULLY PARSED DBLP:conf/oss/0001SG18: " Leaving Behind the Software History When Transitioning to Op ... "
# SUCESSFULLY PARSED DBLP:conf/sbes/VazMS18: " An empirical study on task documentation in software crowdso ... "
# SUCESSFULLY PARSED DBLP:conf/sbes/FerreiraS0SM18: " When students become contributors: leveraging {OSS} contribu ... "
# SUCESSFULLY PARSED DBLP:conf/sbes/SilvaGSC18: " What are the differences between group and individual modeli ... "
# SUCESSFULLY PARSED DBLP:conf/csee/PintoFSG17: " Training Software Engineers Using Open-Source Software: The  ... "
# SUCESSFULLY PARSED DBLP:conf/csee/SilvaSC17: " Is It Better to Learn from Problems or Erroneous Examples?  "
# SUCESSFULLY PARSED DBLP:conf/icse/DinizSGS17: " Using Gamification to Orient and Motivate Students to Contri ... "
# SUCESSFULLY PARSED DBLP:conf/icsm/SilvaWGSG17: " How Long and How Much: What to Expect from Summer of Code Pa ... "
# SUCESSFULLY PARSED DBLP:conf/sbes/SilvaWSG17: " Students' Engagement in Open Source Projects: An Analysis of ... "
# SUCESSFULLY PARSED DBLP:conf/icse/SteinmacherCTG16: " Overcoming open source project entry barriers with a portal  ... "
# SUCESSFULLY PARSED DBLP:conf/icsm/WieseSSTG16: " Who is Who in the Mailing List? Comparing Six Disambiguation ... "
# SUCESSFULLY PARSED DBLP:conf/icsm/DiasSPCG16: " How Does the Shift to GitHub Impact Project Collaboration?  "
# SUCESSFULLY PARSED DBLP:conf/sbes/NascimentoSCSMT16: " Is a Picture worth a Thousand Words?: {A} Comparative Analys ... "
# SUCESSFULLY PARSED DBLP:conf/sigsoft/SarmaGSL16: " Training the future workforce through task curation in an {O ... "
# SUCESSFULLY PARSED DBLP:conf/wcre/PintoSG16: " More Common Than You Think: An In-depth Study of Casual Cont ... "
# WARNING Missing Expected Field 'booktitle' from entry DBLP:phd/ndltd/Steinmacher15: " Apoiando novatos a superarem b ... "
# SUCESSFULLY PARSED DBLP:conf/cscw/SteinmacherCGR15: " Social Barriers Faced by Newcomers Placing Their First Contr ... "
# SUCESSFULLY PARSED DBLP:conf/hicss/SteinmacherCG15: " Understanding and Supporting the Choice of an Appropriate Ta ... "
# SUCESSFULLY PARSED DBLP:conf/iceis/GeraldiOCS15: " Checklist-based Inspection of SMarty Variability Models - Pr ... "
# SUCESSFULLY PARSED DBLP:conf/icse/RabeloOSBSSC15: " Knowledge Management and Organizational Culture in a Softwar ... "
# SUCESSFULLY PARSED DBLP:conf/sbes/WieseRSKOG15: " Predicting Change Propagation from Repository Information  "
# SUCESSFULLY PARSED DBLP:conf/sbes/SteinmacherWCG15: " Increasing the Self-Efficacy of Newcomers to Open Source Sof ... "
# SUCESSFULLY PARSED DBLP:conf/criwg/SteinmacherG14: " Choosing an Appropriate Task to Start with in Open Source So ... "
# SUCESSFULLY PARSED DBLP:conf/icse/SteinmacherWCGR14: " The hard life of open source software project newcomers  "
# SUCESSFULLY PARSED DBLP:conf/oss/SteinmacherSG14: " Barriers Faced by Newcomers to Open Source Projects: {A} Sys ... "
# SUCESSFULLY PARSED DBLP:conf/oss/SteinmacherG14: " How to Support Newcomers Onboarding to Open Source Software  ... "
# SUCESSFULLY PARSED DBLP:conf/promise/WieseCRSG14: " Social metrics included in prediction models on software eng ... "
# SUCESSFULLY PARSED DBLP:conf/sbes/SteinmacherCCG14: " Preliminary Empirical Identification of Barriers Faced by Ne ... "
# SUCESSFULLY PARSED DBLP:conf/icse/SteinmacherWCG13: " Why do newcomers abandon open source software projects?  "
# SUCESSFULLY PARSED DBLP:conf/iwpse/OlivaSWG13: " What can commit metadata tell us about design degradation?  "
# SUCESSFULLY PARSED DBLP:conf/icgse/SilvaGWRS12: " An Extensible Service for Experts Recommendation on Distribu ... "
# SUCESSFULLY PARSED DBLP:conf/icse/SteinmacherWG12: " Recommending mentors to software project newcomers  "
# SUCESSFULLY PARSED DBLP:conf/sbsc/SteinmacherWCG12: " Newcomers Withdrawal in Open Source Software Projects: Analy ... "
# SUCESSFULLY PARSED DBLP:conf/sbsc/NishiCS12: " A Collective Intelligence Based System for Visualizing Probl ... "
# SUCESSFULLY PARSED DBLP:conf/sbsc/SchwerzLWSGF12: " Prediction of Developer Participation in Issues of Open Sour ... "
# SUCESSFULLY PARSED DBLP:conf/criwg/SteinmacherCG10: " Awareness Support in Global Software Development: {A} System ... "
# SUCESSFULLY PARSED DBLP:conf/seke/ChavesHVS10: " A Context Conceptual Model for a Distributed Software Develo ... "
# SUCESSFULLY PARSED DBLP:conf/seke/SteinmacherLH06: " Task Anticipation: {A} Quantitative Analysis Using Workflow  ... "
# SUCESSFULLY PARSED DBLP:journals/jss/SilvaWGTGS20: " Google summer of code: Student motivations and contributions  "
# SUCESSFULLY PARSED DBLP:journals/access/SilvaSC19: " Students' and Instructors' Perceptions of Five Different Act ... "
# SUCESSFULLY PARSED DBLP:journals/cscw/SteinmacherGCR19: " Overcoming Social Barriers When Contributing to Open Source  ... "
# SUCESSFULLY PARSED DBLP:journals/software/SteinmacherTG19: " Let Me In: Guidelines for the Successful Onboarding of Newco ... "
# SUCESSFULLY PARSED DBLP:journals/software/RoblesSAT19: " Twenty Years of Open Source Software: From Skepticism to Mai ... "
# SUCESSFULLY PARSED DBLP:journals/sqj/WieseKSORTG19: " Pieces of contextual information suitable for predicting co- ... "
# SUCESSFULLY PARSED DBLP:journals/corr/abs-1903-09528: " Why do developers take breaks from contributing to {OSS} pro ... "
# SUCESSFULLY PARSED DBLP:journals/corr/abs-1910-05798: " Google Summer of Code: Student Motivations and Contributions  "
# SUCESSFULLY PARSED DBLP:journals/corr/abs-1911-04016: " Untapped potential for software engineering in an emerging s ... "
# SUCESSFULLY PARSED DBLP:journals/cscw/BalaliSASG18: " Newcomers' Barriers. . . Is That All? An Analysis of Mentors ... "
# SUCESSFULLY PARSED DBLP:journals/ese/PintoSDG18: " On the challenges of open-sourcing proprietary software proj ... "
# SUCESSFULLY PARSED DBLP:journals/jbcs/DiasSP18: " Who drives company-owned {OSS} projects: internal or externa ... "
# SUCESSFULLY PARSED DBLP:journals/jbcs/NeiraSW18: " Characterizing the hyperspecialists in the context of crowds ... "
# SUCESSFULLY PARSED DBLP:journals/pacmhci/WesselSSWPCG18: " The Power of Bots: Characterizing and Understanding Bots in  ... "
# SUCESSFULLY PARSED DBLP:journals/jisa/SteinmacherRFW17: " Free and open source software development: the end of the te ... "
# SUCESSFULLY PARSED DBLP:journals/jss/WieseRSKOTG17: " Using contextual information to predict co-changes  "
# SUCESSFULLY PARSED DBLP:journals/software/ZanattaSMSP17: " Barriers Faced by Newcomers to Software-Crowdsourcing Projec ... "
# SUCESSFULLY PARSED DBLP:journals/infsof/SteinmacherSGR15: " A systematic literature review on the barriers faced by newc ... "
# SUCESSFULLY PARSED DBLP:journals/eceasst/WieseJRSG14: " Comparing communication and development networks for predict ... "
# SUCESSFULLY PARSED DBLP:journals/cscw/SteinmacherCG13: " Awareness Support in Distributed Software Development: {A} S ... "
# SUCESSFULLY PARSED DBLP:journals/cleiej/ChavesSLHB11: " OntoDiSENv1: an Ontology to Support Global Software Developm ... "
